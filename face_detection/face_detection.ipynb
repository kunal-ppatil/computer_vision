# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\kunal\.conda\envs\yolo-env1\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\kunal\.conda\envs\yolo-env1\lib\site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
a=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
b=cv2.VideoCapture(0)

while True:
    c_rec,d_image=b.read()
    e=cv2.cvtColor(d_image,cv2.COLOR_BGR2GRAY)
    f=a.detectMultiScale(e,1.3,6)

    for(x1,y1,w1,h1) in f:
        cv2.rectangle(d_image,(x1,y1),(x1+w1, y1+h1),(255,0,0))
    cv2.imshow('img',d_image)
    h=cv2.waitKey(40) & 0xff 
    if h==40:
        break
b.release()
cv2.destroyAllWindows()

# %%
b.release()
cv2.destroyAllWindows()
